# %% [markdown]
# ***the problem statement is predict the student mark whether using machine learning model***

# %%
#import libraries
import numpy as np #using data handling
import pandas as pd #read the dataset and data handling
import matplotlib.pyplot as plt #visuavalize the data
import seaborn as sns #advanced visuavalization
from sklearn.linear_model import LinearRegression #ml algorithm regression
from sklearn.model_selection import train_test_split #splitting dataset
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score #predict the r2 score

# %% [markdown]
# **load dataset**

# %%
stud_mark=pd.read_csv('data.csv')
stud_mark.head()
# Out:
#     1st   2nd   3rd   4th   5th  College Code  Gender  Roll  Roll no.  \
# 0  8.11  7.68  7.11  7.43  8.18           115  Female   NaN   17020.0
# 1  6.48  5.90  4.15  4.29  4.96           115    Male   NaN   17021.0
# 2  8.41  8.24  7.52  8.25  7.75           115  Female   NaN   17022.0
# 3  7.33  6.83  6.33  6.79  6.89           115    Male   NaN   17023.0
# 4  7.89  7.34  7.22  7.32  7.46           115    Male   NaN   17024.0
#
#    Subject Code
# 0            16
# 1            16
# 2            16
# 3            16
# 4            16

# %%
stud_mark.shape
# Out:
# (178, 10)

# %%
stud_mark=stud_mark.drop(columns=['Roll','Roll no.','College Code','Subject Code'])

# %%
stud_mark.head()
# Out:
#     1st   2nd   3rd   4th   5th  Gender
# 0  8.11  7.68  7.11  7.43  8.18  Female
# 1  6.48  5.90  4.15  4.29  4.96    Male
# 2  8.41  8.24  7.52  8.25  7.75  Female
# 3  7.33  6.83  6.33  6.79  6.89    Male
# 4  7.89  7.34  7.22  7.32  7.46    Male

# %%
#stud_mark.shape
stud_mark.isnull().sum()
# Out:
# 1st       2
# 2nd       4
# 3rd       2
# 4th       5
# 5th       6
# Gender    1
# dtype: int64

# %%
stud_mark['5th'].value_counts()
# Out:
# 5th
# 7.00    6
# 8.21    6
# 6.75    5
# 6.18    4
# 8.36    4
#        ..
# 4.77    1
# 5.81    1
# 7.04    1
# 6.50    1
# 6.92    1
# Name: count, Length: 100, dtype: int64

# %%
#using fillna method for all columns numeric_only function using
stud_mark=stud_mark.fillna(stud_mark.mean(numeric_only=True))

# %%
#using mode for categorical data only
stud_mark['Gender']=stud_mark['Gender'].fillna(stud_mark['Gender'].mode()[0])
stud_mark['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
#stud_mark.isnull().sum()
#print(stud_mark.info()) information of the dataset
print(stud_mark.describe()) #statistical summmary
# Out:
#               1st         2nd         3rd         4th         5th
# count  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     7.038864    6.943391    6.622500    7.027746    7.432558
# std      0.854651    0.871075    0.914052    1.020942    1.050594
# min      3.850000    3.900000    3.960000    4.290000    4.000000
# 25%      6.450000    6.380000    6.160000    6.360000    6.760000
# 50%      7.055000    6.845000    6.650000    7.040000    7.520000
# 75%      7.590000    7.590000    7.250000    7.820000    8.210000
# max      9.150000    9.210000    9.590000    9.310000    9.460000

# %%
#exploratory data analysis
sns.histplot(stud_mark['3rd'],kde=True)
# Out:
# <Axes: xlabel='3rd', ylabel='Count'>

# %%
#check outliers
sns.boxplot(stud_mark['5th']) #outliers will be find out better option these are remove only
# Out:
# <Axes: ylabel='5th'>

# %%
#remove outliers
cols = ['1st', '2nd', '3rd','5th']

for col in cols:
    Q1 = stud_mark[col].quantile(0.25)
    Q3 = stud_mark[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    stud_mark = stud_mark[
        (stud_mark[col] >= lower) & 
        (stud_mark[col] <= upper)
    ]

print(stud_mark.shape)
# Out:
# (165, 6)

# %%
sns.boxplot(stud_mark['5th'])
# Out:
# <Axes: ylabel='5th'>

# %%
#scatter plot
plt.scatter(stud_mark['3rd'],stud_mark['4th'],c=stud_mark['5th'])
plt.xlabel("count")
plt.ylabel("data")
plt.title("two semester marks compared")
plt.tight_layout()
plt.legend()
# Out:
# C:\Users\Vishwa\AppData\Local\Temp\ipykernel_4284\2693472243.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.heatmap(stud_mark.corr(),annot=True)
# Out:
# <Axes: >

# %%
#encoding method
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
stud_mark['Gender']=le.fit_transform(stud_mark['Gender'])
stud_mark.head()
# Out:
#     1st   2nd   3rd   4th   5th  Gender
# 0  8.11  7.68  7.11  7.43  8.18       1
# 2  8.41  8.24  7.52  8.25  7.75       1
# 3  7.33  6.83  6.33  6.79  6.89       3
# 4  7.89  7.34  7.22  7.32  7.46       3
# 5  7.33  6.72  6.48  6.50  7.39       3

# %%
stud_mark['Gender'].value_counts()
# Out:
# Gender
# 3    74
# 2    65
# 1    16
# 0    10
# Name: count, dtype: int64

# %%
#splitting features and labels
x=stud_mark[['1st','2nd','3rd','4th']]
x
# Out:
#       1st   2nd   3rd   4th
# 0    8.11  7.68  7.11  7.43
# 2    8.41  8.24  7.52  8.25
# 3    7.33  6.83  6.33  6.79
# 4    7.89  7.34  7.22  7.32
# 5    7.33  6.72  6.48  6.50
# ..    ...   ...   ...   ...
# 173  7.48  7.55  7.67  7.39
# 174  7.30  6.41  6.59  7.11
# 175  6.30  6.28  5.89  5.71
# 176  7.04  7.10  6.81  7.00
# 177  6.70  6.81  6.52  5.39
#
# [165 rows x 4 columns]

# %%
y=stud_mark['5th']
y
# Out:
# 0      8.18
# 2      7.75
# 3      6.89
# 4      7.46
# 5      7.39
#        ...
# 173    8.65
# 174    7.38
# 175    6.50
# 176    6.92
# 177    7.00
# Name: 5th, Length: 165, dtype: float64

# %%
#splitting train test split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

print(x_train)
# Out:
#       1st   2nd   3rd   4th
# 128  6.74  6.72  7.04  7.93
# 101  6.85  7.41  7.41  7.86
# 145  7.07  7.66  7.22  7.86
# 38   7.59  7.38  7.30  8.64
# 89   7.37  7.93  7.07  7.64
# ..    ...   ...   ...   ...
# 78   7.11  7.07  6.07  5.86
# 115  9.15  8.86  8.34  9.04
# 16   6.96  6.14  6.93  7.18
# 99   5.93  5.86  4.70  5.50
# 111  7.89  8.72  8.19  8.54
#
# [123 rows x 4 columns]

# %%
#random forest algorithm using
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
#predict test data
y_pred=RFR.predict(x_test)
print(y_pred)
# Out:
# [6.49993023 6.8755     8.9364     7.48245349 7.91317674 8.381
#  7.95147674 8.8549     7.45752558 8.313      8.6959     6.48140465
#  6.57635349 7.54153023 7.11837674 8.1618     7.55402791 7.9812
#  7.2842     8.1477     8.1102     6.4912     7.0001     8.2063
#  8.3699     7.59672558 8.372      7.9603     8.5097     7.2895814
#  6.87713023 7.04405349 7.8728     7.59809302 7.52232791 6.5466
#  8.4997     8.0541     6.84655581 7.33706047 8.0849     6.19552558]

# %% [markdown]
# ***model evaluation***

# %%
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 0.405202491694351
# 0.29910614569071986
# 0.7328304863003983

# %%
import pickle
pickle.dump(RFR, open('model.pkl', 'wb'))
print("Model saved!")
# Out:
# Model saved!

# %%
model=pickle.load(open('model.pkl','rb'))
print(model)
# Out:
# RandomForestRegressor()
